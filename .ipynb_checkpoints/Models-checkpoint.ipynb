# %%
import pandas as pd
import numpy as np
import geopandas as gpd
import matplotlib.pyplot as plt
from shapely.geometry import Point, Polygon
from geopandas.tools import sjoin
import pysal as ps
import numpy as np
# %matplotlib inline

# %%
data=pd.read_csv('InputDataset.csv',dtype={'BGFIPS10':np.object}).set_index('BGFIPS10')
geo=gpd.read_file('Data/SF_BlockGroups10.shp').set_index('BGFIPS10')
gdf=gpd.GeoDataFrame(data, geometry=geo.geometry)

# %%
w=ps.queen_from_shapefile('Data/SF_BlockGroups10.shp', 'BGFIPS10')
# Out:
# WARNING: there is one disconnected observation (no neighbors)
# Island id:  [576]

# %%
n, bins, patches = plt.hist(w.cardinalities.values(), 25, facecolor='green', alpha=0.75)

plt.xlabel('Number of Neighbors')
plt.ylabel('Count')
plt.title('SF Block Group Connectivity: Queen Adjacency Neighbors')
plt.grid(True)

# %%
islandid=[k for k,v in w.cardinalities.iteritems() if v==0][0]
p=gpd.GeoSeries(geo.loc[islandid]).plot()

# %%
idmax=pd.Series(w.cardinalities).idxmax()
p=gpd.GeoSeries(geo.loc[idmax]).plot()

# %%
neigh_ids=w.neighbors[idmax]
p=geo.loc[neigh_ids].plot()

# %%
data=data[~data.index.isin([idmax, islandid,'060750179021'])]
geo=geo[~geo.index.isin([idmax, islandid,'060750179021'])]
geo.reset_index().to_file('Data/SF_BlockGroups10_Cleaned.shp')
gdf=gpd.GeoDataFrame(data, geometry=geo.geometry)
w=ps.queen_from_shapefile('Data/SF_BlockGroups10_Cleaned.shp', 'BGFIPS10')

# %%
w.weights.values()[4]
# Out:
# [1.0, 1.0, 1.0, 1.0]

# %%
w.transform='r'
w.weights.values()[4]
# Out:
# [0.25, 0.25, 0.25, 0.25]

# %%
gdf.plot(column='RetailPSqMi', scheme='QUANTILES', colormap='OrRd')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-78-c647e92fc01e> in <module>()
# ----> 1 gdf.plot(column='RetailPSqMi', scheme='QUANTILES', colormap='OrRd')
#
# C:\Anaconda\lib\site-packages\geopandas\geodataframe.pyc in plot(self, *args, **kwargs)
#     415
#     416     def plot(self, *args, **kwargs):
# --> 417         return plot_dataframe(self, *args, **kwargs)
#     418
#     419
#
# C:\Anaconda\lib\site-packages\geopandas\plotting.pyc in plot_dataframe(s, column, colormap, categorical, legend, axes, scheme, k, **color_kwds)
#     201             ax = axes
#     202         for geom, value in zip(s.geometry, values):
# --> 203             if geom.type == 'Polygon' or geom.type == 'MultiPolygon':
#     204                 plot_multipolygon(ax, geom, facecolor=cmap.to_rgba(value), **color_kwds)
#     205             elif geom.type == 'LineString' or geom.type == 'MultiLineString':
#
# AttributeError: 'float' object has no attribute 'type'

# %% [markdown]
# Some more the more highly correlated varibles are not surprising - Retail density and bar density, poverty and bar density, poverty and retail, population density and retail density, population and bar density.

# %%
data.corr()
# Out:
#              AssaultP1k  DrunkP1k  BarPSqMi  RetailPSqMi       Pop  PopDens1k  \
# AssaultP1k     1.000000  0.725605  0.247531     0.240195 -0.094363   0.006791
# DrunkP1k       0.725605  1.000000  0.360576     0.355957 -0.043290   0.057741
# BarPSqMi       0.247531  0.360576  1.000000     0.553694  0.054458   0.463964
# RetailPSqMi    0.240195  0.355957  0.553694     1.000000  0.034091   0.404161
# Pop           -0.094363 -0.043290  0.054458     0.034091  1.000000   0.269359
# PopDens1k      0.006791  0.057741  0.463964     0.404161  0.269359   1.000000
# pMale          0.264968  0.256699  0.220390     0.085941  0.022407   0.137638
# MedAge        -0.029781 -0.013781 -0.039421    -0.021245 -0.247729  -0.094259
# pHHPov         0.412018  0.327270  0.312558     0.314269  0.089226   0.373603
# VacantHU       0.362846  0.332012  0.196937     0.150127 -0.056524   0.086698
#
#                 pMale    MedAge    pHHPov  VacantHU
# AssaultP1k   0.264968 -0.029781  0.412018  0.362846
# DrunkP1k     0.256699 -0.013781  0.327270  0.332012
# BarPSqMi     0.220390 -0.039421  0.312558  0.196937
# RetailPSqMi  0.085941 -0.021245  0.314269  0.150127
# Pop          0.022407 -0.247729  0.089226 -0.056524
# PopDens1k    0.137638 -0.094259  0.373603  0.086698
# pMale        1.000000 -0.018096  0.021370  0.151776
# MedAge      -0.018096  1.000000  0.014789 -0.017283
# pHHPov       0.021370  0.014789  1.000000  0.204956
# VacantHU     0.151776 -0.017283  0.204956  1.000000

# %%
f=data.plot.scatter('BarPSqMi','AssaultP1k')
f=data.plot.scatter('BarPSqMi','pHHPov')
f=data.plot.scatter('BarPSqMi','RetailPSqMi')

# %%
VarLabels={'AssaultP1k':'Assaults per 1k', 'DrunkP1k':'Drunk per 1k', 'pHHPov':'% HH in Poverty',
           'BarPSqMi':'Bars per SqMi', 'RetailPSqMi':'Retail per SqMi','PopDens1k':'Pop Density (x1000)',
           'pMale':'% Male','MedAge':'Median Age','VacantHU':'% Vacant Housing'}

# %%
YVar='DrunkP1k'
XVars=['pHHPov','BarPSqMi','RetailPSqMi','PopDens1k','pMale','VacantHU','MedAge']
#XVars=['BarPSqMi']

Y=data[YVar].as_matrix().reshape((len(data),1))
X=data[XVars].as_matrix()

print Y.shape, X.shape
# Out:
# (576, 1) (576, 7)

# %%
ols1=ps.spreg.OLS(Y,X,w=w, spat_diag=True,moran=True,name_y=VarLabels[YVar], name_x=[VarLabels[v] for v in XVars])
print ols1.summary
# Out:
# REGRESSION
# ----------
# SUMMARY OF OUTPUT: ORDINARY LEAST SQUARES
# -----------------------------------------
# Data set            :     unknown
# Weights matrix      :     unknown
# Dependent Variable  :Drunk per 1k                Number of Observations:         576
# Mean dependent var  :      4.4691                Number of Variables   :           8
# S.D. dependent var  :     11.9603                Degrees of Freedom    :         568
# R-squared           :      0.3350
# Adjusted R-squared  :      0.3268
# Sum squared residual:   54701.126                F-statistic           :     40.8697
# Sigma-square        :      96.305                Prob(F-statistic)     :   1.339e-46
# S.E. of regression  :       9.814                Log likelihood        :   -2128.726
# Sigma-square ML     :      94.967                Akaike info criterion :    4273.452
# S.E of regression ML:      9.7451                Schwarz criterion     :    4308.300
#
# ------------------------------------------------------------------------------------
#             Variable     Coefficient       Std.Error     t-Statistic     Probability
# ------------------------------------------------------------------------------------
#             CONSTANT     -14.2815681       3.8371760      -3.7218956       0.0002174
#      % HH in Poverty       0.2559254       0.0396547       6.4538516       0.0000000
#        Bars per SqMi       0.0524135       0.0119248       4.3953303       0.0000132
#      Retail per SqMi       0.0187258       0.0034608       5.4108925       0.0000001
#  Pop Density (x1000)      -0.1447544       0.0224409      -6.4504622       0.0000000
#               % Male       0.3164752       0.0579200       5.4640048       0.0000001
#     % Vacant Housing       0.3430379       0.0607874       5.6432417       0.0000000
#           Median Age      -0.0391032       0.0590142      -0.6626065       0.5078514
# ------------------------------------------------------------------------------------
#
# REGRESSION DIAGNOSTICS
# MULTICOLLINEARITY CONDITION NUMBER           27.519
#
# TEST ON NORMALITY OF ERRORS
# TEST                             DF        VALUE           PROB
# Jarque-Bera                       2       34885.846           0.0000
#
# DIAGNOSTICS FOR HETEROSKEDASTICITY
# RANDOM COEFFICIENTS
# TEST                             DF        VALUE           PROB
# Breusch-Pagan test                7        2160.047           0.0000
# Koenker-Bassett test              7         110.920           0.0000
#
# DIAGNOSTICS FOR SPATIAL DEPENDENCE
# TEST                           MI/DF       VALUE           PROB
# Moran's I (error)              0.2360        10.199           0.0000
# Lagrange Multiplier (lag)         1         149.965           0.0000
# Robust LM (lag)                   1          55.639           0.0000
# Lagrange Multiplier (error)       1          96.711           0.0000
# Robust LM (error)                 1           2.385           0.1225
# Lagrange Multiplier (SARMA)       2         152.350           0.0000
#
# ================================ END OF REPORT =====================================

# %%
gpd.GeoDataFrame(ols1.u,geometry=geo.geometry.reset_index(drop=True)).plot(column=0, scheme='QUANTILES', colormap='OrRd')

# %%
lag1=ps.spreg.ML_Lag(Y, X, w, name_y=VarLabels[YVar], name_x=[VarLabels[v] for v in XVars])
print lag1.summary
# Out:
# REGRESSION
# ----------
# SUMMARY OF OUTPUT: MAXIMUM LIKELIHOOD SPATIAL LAG (METHOD = FULL)
# -----------------------------------------------------------------
# Data set            :     unknown
# Weights matrix      :     unknown
# Dependent Variable  :Drunk per 1k                Number of Observations:         576
# Mean dependent var  :      4.4691                Number of Variables   :           9
# S.D. dependent var  :     11.9603                Degrees of Freedom    :         567
# Pseudo R-squared    :      0.5100
# Spatial Pseudo R-squared:  0.3750
# Sigma-square ML     :      70.500                Log likelihood        :   -2062.533
# S.E of regression   :       8.396                Akaike info criterion :    4143.066
#                                                  Schwarz criterion     :    4182.271
#
# ------------------------------------------------------------------------------------
#             Variable     Coefficient       Std.Error     z-Statistic     Probability
# ------------------------------------------------------------------------------------
#             CONSTANT      -5.5624780       3.2956517      -1.6878234       0.0914451
#      % HH in Poverty       0.1487851       0.0343148       4.3358886       0.0000145
#        Bars per SqMi       0.0431625       0.0102302       4.2191414       0.0000245
#      Retail per SqMi       0.0150447       0.0029761       5.0551735       0.0000004
#  Pop Density (x1000)      -0.1569228       0.0192391      -8.1564694       0.0000000
#               % Male       0.1768127       0.0502981       3.5152981       0.0004393
#     % Vacant Housing       0.2230736       0.0523520       4.2610335       0.0000203
#           Median Age      -0.0671475       0.0505206      -1.3291095       0.1838118
#       W_Drunk per 1k       0.5836502       0.0413529      14.1138902       0.0000000
# ------------------------------------------------------------------------------------
# ================================ END OF REPORT =====================================

# %%
lag2=ps.spreg.GM_Lag(Y, X, w=w, name_y=VarLabels[YVar], name_x=[VarLabels[v] for v in XVars])
print lag2.summary
# Out:
# REGRESSION
# ----------
# SUMMARY OF OUTPUT: SPATIAL TWO STAGE LEAST SQUARES
# --------------------------------------------------
# Data set            :     unknown
# Weights matrix      :     unknown
# Dependent Variable  :Drunk per 1k                Number of Observations:         576
# Mean dependent var  :      4.4691                Number of Variables   :           9
# S.D. dependent var  :     11.9603                Degrees of Freedom    :         567
# Pseudo R-squared    :      0.5232
# Spatial Pseudo R-squared:  0.3210
#
# ------------------------------------------------------------------------------------
#             Variable     Coefficient       Std.Error     z-Statistic     Probability
# ------------------------------------------------------------------------------------
#             CONSTANT      -2.2823728       3.4727670      -0.6572202       0.5110393
#      % HH in Poverty       0.1084791       0.0368895       2.9406492       0.0032753
#        Bars per SqMi       0.0396822       0.0101200       3.9211682       0.0000881
#      Retail per SqMi       0.0136598       0.0029603       4.6143463       0.0000039
#  Pop Density (x1000)      -0.1615005       0.0189561      -8.5197155       0.0000000
#               % Male       0.1242720       0.0528692       2.3505555       0.0187454
#     % Vacant Housing       0.1779432       0.0540832       3.2901729       0.0010013
#           Median Age      -0.0776977       0.0497983      -1.5602488       0.1187011
#       W_Drunk per 1k       0.8032182       0.0859305       9.3472989       0.0000000
# ------------------------------------------------------------------------------------
# Instrumented: W_Drunk per 1k
# Instruments: W_% HH in Poverty, W_% Male, W_% Vacant Housing, W_Bars per
#              SqMi, W_Median Age, W_Pop Density (x1000), W_Retail per SqMi
# ================================ END OF REPORT =====================================

# %%
b=lag1.betas[:-1]
rho=lag1.betas[-1]
btot=b/(1.0-rho)
bind=btot-b

#pd.DataFrame([b,bind])

pd.DataFrame(np.hstack([b,bind,btot]),index=['Constant']+XVars, columns=['Direct','Indirect','Total'])
# Out:
#                Direct  Indirect      Total
# Constant    -5.562478 -7.797628 -13.360106
# pHHPov       0.148785  0.208571   0.357356
# BarPSqMi     0.043162  0.060506   0.103669
# RetailPSqMi  0.015045  0.021090   0.036135
# PopDens1k   -0.156923 -0.219979  -0.376901
# pMale        0.176813  0.247861   0.424673
# VacantHU     0.223074  0.312710   0.535784
# MedAge      -0.067147 -0.094129  -0.161277

# %%
#error one
error1=ps.spreg.ML_Error(Y, X, w=w, name_y=VarLabels[YVar], name_x=[VarLabels[v] for v in XVars])
print error1.summary
# Out:
# REGRESSION
# ----------
# SUMMARY OF OUTPUT: MAXIMUM LIKELIHOOD SPATIAL ERROR (METHOD = FULL)
# -------------------------------------------------------------------
# Data set            :     unknown
# Weights matrix      :     unknown
# Dependent Variable  :Drunk per 1k                Number of Observations:         576
# Mean dependent var  :      4.4691                Number of Variables   :           8
# S.D. dependent var  :     11.9603                Degrees of Freedom    :         568
# Pseudo R-squared    :      0.2628
# Sigma-square ML     :      71.593                Log likelihood        :   -2073.987
# S.E of regression   :       8.461                Akaike info criterion :    4163.973
#                                                  Schwarz criterion     :    4198.822
#
# ------------------------------------------------------------------------------------
#             Variable     Coefficient       Std.Error     z-Statistic     Probability
# ------------------------------------------------------------------------------------
#             CONSTANT       1.3693416       3.9064589       0.3505327       0.7259390
#      % HH in Poverty       0.1149782       0.0398152       2.8877978       0.0038795
#        Bars per SqMi       0.0403665       0.0105994       3.8083661       0.0001399
#      Retail per SqMi       0.0167752       0.0032598       5.1461560       0.0000003
#  Pop Density (x1000)      -0.1936241       0.0259587      -7.4589265       0.0000000
#               % Male       0.1679206       0.0547408       3.0675567       0.0021582
#     % Vacant Housing       0.1960216       0.0536709       3.6522857       0.0002599
#           Median Age      -0.1154311       0.0564896      -2.0434054       0.0410123
#               lambda       0.6625291       0.0415466      15.9466659       0.0000000
# ------------------------------------------------------------------------------------
# ================================ END OF REPORT =====================================

# %%
#spatial durbin
LagX = ps.lag_spatial(w, X)
NewX = np.hstack((X,LagX)) 
NewXNames=XVars+[x+'lag' for x in XVars]
durbin1=ps.spreg.ML_Lag(Y, NewX, w, name_y=YVar, name_x=NewXNames)
print durbin1.summary
# Out:
# REGRESSION
# ----------
# SUMMARY OF OUTPUT: MAXIMUM LIKELIHOOD SPATIAL LAG (METHOD = FULL)
# -----------------------------------------------------------------
# Data set            :     unknown
# Weights matrix      :     unknown
# Dependent Variable  :    DrunkP1k                Number of Observations:         576
# Mean dependent var  :      4.4691                Number of Variables   :          16
# S.D. dependent var  :     11.9603                Degrees of Freedom    :         560
# Pseudo R-squared    :      0.5240
# Spatial Pseudo R-squared:  0.4248
# Sigma-square ML     :      68.213                Log likelihood        :   -2048.172
# S.E of regression   :       8.259                Akaike info criterion :    4128.344
#                                                  Schwarz criterion     :    4198.041
#
# ------------------------------------------------------------------------------------
#             Variable     Coefficient       Std.Error     z-Statistic     Probability
# ------------------------------------------------------------------------------------
#             CONSTANT     -19.3793757       6.0847446      -3.1849120       0.0014480
#               pHHPov       0.0790487       0.0397438       1.9889567       0.0467060
#             BarPSqMi       0.0315610       0.0107423       2.9380045       0.0033033
#          RetailPSqMi       0.0153920       0.0032745       4.7005757       0.0000026
#            PopDens1k      -0.2414750       0.0289035      -8.3545142       0.0000000
#                pMale       0.1557031       0.0539629       2.8853714       0.0039095
#             VacantHU       0.1749103       0.0534872       3.2701346       0.0010750
#               MedAge      -0.1378991       0.0557183      -2.4749350       0.0133260
#            pHHPovlag       0.1958765       0.0668428       2.9304050       0.0033852
#          BarPSqMilag      -0.0177907       0.0223672      -0.7953925       0.4263852
#       RetailPSqMilag       0.0046412       0.0067464       0.6879452       0.4914873
#         PopDens1klag       0.1286337       0.0477052       2.6964309       0.0070087
#             pMalelag       0.1295474       0.0963299       1.3448300       0.1786801
#          VacantHUlag       0.0740667       0.1209186       0.6125335       0.5401849
#            MedAgelag       0.2110743       0.0946830       2.2292729       0.0257958
#           W_DrunkP1k       0.5160222       0.0500306      10.3141274       0.0000000
# ------------------------------------------------------------------------------------
# ================================ END OF REPORT =====================================
